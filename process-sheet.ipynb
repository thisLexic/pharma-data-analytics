# %%
import numpy as np
import pandas as pd

# %%
# For displaying all the cells
# pd.set_option("display.max_rows", None, "display.max_columns", None)

# %%
feb02 = pd.read_excel('media/feb-02-2020-mauban.xlsx',sheet_name='PDFTables.com')

# %%
feb02.rename(columns={'Detailed POS Sales Report': 'ID'}, inplace=True)
feb02.rename(columns={'Unnamed: 7': 'Qty'}, inplace=True)

# %%
# remove records with non-integer IDs
feb02 = feb02[feb02['ID'].apply(lambda x: isinstance(x, int))]

# %%
feb02
# Out:
#        ID Unnamed: 1   Unnamed: 2 Unnamed: 3    Unnamed: 4 Unnamed: 5  \
# 5    1224        NaN   MANGOSTEEN        NaN           MX3     COFFEE
# 6     988        ONE          NaN      TOUCH        SELECT     STRIPS
# 7    1004        NaN    ONE TOUCH        NaN  LANCET ULTRA        NaN
# 8     210        NaN          NaN        NaN           NaN        NaN
# 10    988        ONE          NaN      TOUCH        SELECT     STRIPS
# ..    ...        ...          ...        ...           ...        ...
# 804   105        NaN          NaN        NaN           NaN        NaN
# 806   144        NaN     LOSARTAN        NaN           NaN      T50MG
# 807  1504        NaN        GREEN        NaN           NaN      CROSS
# 808  1251        NaN  CLOPIDOGREL        NaN           NaN        NaN
# 811   195        NaN          NaN        NaN          PARA    S125/60
#
#     Unnamed: 6         Qty 29/12/2020 Unnamed: 9 Unnamed: 10 Unnamed: 11
# ...
